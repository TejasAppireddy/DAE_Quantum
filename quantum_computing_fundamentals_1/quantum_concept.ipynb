# %%
# !pip3 install qiskit
# Out:
# Requirement already satisfied: qiskit in ./.venv/lib/python3.14/site-packages (2.5.0)
# Requirement already satisfied: numpy<3,>=2.0 in ./.venv/lib/python3.14/site-packages (from qiskit) (2.5.1)
# Requirement already satisfied: scipy>=1.14 in ./.venv/lib/python3.14/site-packages (from qiskit) (1.18.0)
# Requirement already satisfied: rustworkx>=0.15.0 in ./.venv/lib/python3.14/site-packages (from qiskit) (0.18.0)
# Requirement already satisfied: dill>=0.3 in ./.venv/lib/python3.14/site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in ./.venv/lib/python3.14/site-packages (from qiskit) (5.9.0)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.14/site-packages (from qiskit) (4.16.0)

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.measure(qreg_q[0], creg_c[0])
print(circuit.draw(output='text'))
